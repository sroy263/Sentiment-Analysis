# %%
import pandas as pd
df=pd.read_csv('new.csv',encoding='iso-8859-13')

# %%
bl=df['Source']=='bloombergquint'

# %%
dfbl=df[bl]

# %%
t=dfbl['Category']!="['politics']"

# %%
dfbl[t]
# Out:
#        Unnamed: 0               Author              Category  \
# 2             2.0        Yuji Nakamura        ['technology']
# 3             3.0  Christopher Palmeri          ['business']
# 4             4.0           Yatin Mota           ['markets']
# 5             5.0          Ameya Karve           ['markets']
# 6             6.0          Jeremy Kahn        ['technology']
# 7             7.0          John Ainger           ['markets']
# 8             8.0        Simon Kennedy  ['global-economics']
# 9             9.0     Arundhati Sarkar  ['global-economics']
# 10           10.0  Jan-Henrik F??rster           ['markets']
# 11           11.0    Anirudh Saligrama           ['markets']
# 12           12.0        Nishant Kumar           ['markets']
# 13           13.0         Todd Shields        ['technology']
# 14           14.0             Ian King        ['technology']
# 15           15.0              BQ Desk          ['business']
# ...

# %%
dfbl
